# %%
import pandas as pd
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
import numpy as np

# Paths to your datasets and labels
train_dataset_dir = r"D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train"
val_dataset_dir = r"D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Val"
test_dataset_dir = r"D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test"

train_labels_file = r"D:\Data_sets\DAiSEE\DAiSEE\Labels\TrainLabels.csv"
val_labels_file = r"D:\Data_sets\DAiSEE\DAiSEE\Labels\ValidationLabels.csv"
test_labels_file = r"D:\Data_sets\DAiSEE\DAiSEE\Labels\TestLabels.csv"

# Function to load dataset and labels
def load_data(dataset_dir, labels_file):
    labels_df = pd.read_csv(labels_file)
    filenames = labels_df['ClipID'].values
    labels = labels_df[['Boredom', 'Engagement', 'Confusion', 'Frustration']].values
    
    data = []
    for filename in filenames:
        # Remove extensions if they exist
        base_filename = os.path.splitext(filename)[0]
        
        # Construct the image path
        img_path = os.path.join(dataset_dir, f"{base_filename}.png")
        
        # Debugging: print the path
        print(f"Checking image path: {img_path}")
        
        if os.path.exists(img_path):
            img = load_img(img_path, target_size=(224, 224))  # Adjust target_size as needed
            img_array = img_to_array(img)
            data.append(img_array)
        else:
            print(f"Image {img_path} not found.")
    
    data = np.array(data)
    
    return data, labels

# Load training data
train_data, train_labels = load_data(train_dataset_dir, train_labels_file)

# Load validation data
val_data, val_labels = load_data(val_dataset_dir, val_labels_file)

# Load test data
test_data, test_labels = load_data(test_dataset_dir, test_labels_file)

# Check shapes to ensure everything loaded correctly
print(f"Train data shape: {train_data.shape}, Train labels shape: {train_labels.shape}")
print(f"Validation data shape: {val_data.shape}, Validation labels shape: {val_labels.shape}")
print(f"Test data shape: {test_data.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011005.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011020.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011056.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011058.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011070.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011071.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011072.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011073.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011075.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011076.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011078.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011079.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011080.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011081.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011082.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100011083.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012041.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012042.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100012069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100021055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022005.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022020.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022056.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100022057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100041052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042020.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042041.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042058.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100042060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051020.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051041.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051042.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051056.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051071.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051076.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051078.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100051079.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052041.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100052070.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061042.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061043.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061058.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061073.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061074.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061077.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100061078.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062005.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062070.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062071.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100062072.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071005.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071020.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071041.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071042.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071043.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071055.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071056.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071058.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071064.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071070.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071071.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071072.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071073.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071074.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071075.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071076.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071077.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071078.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071079.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071080.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100071081.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072031.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072034.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072038.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072039.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072040.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072042.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072043.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072049.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072050.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072051.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072052.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072053.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072054.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072056.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072057.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072058.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072059.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072060.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072061.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072062.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072063.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072065.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072066.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072067.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072068.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072069.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072070.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072071.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072072.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072073.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072074.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072075.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072076.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072077.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072078.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072079.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072080.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072081.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072082.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072083.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072084.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100072085.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100081044.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100081045.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100081046.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100081047.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100081048.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100082002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100082003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100082018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100082027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100102003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111019.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111023.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100111032.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112001.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112002.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112003.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112004.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112006.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112007.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112008.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112009.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112010.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112013.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112021.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112030.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112033.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112035.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112036.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112037.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Train\1100112038.png
# ...
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010259.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\928901026.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010261.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010262.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010263.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010265.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010266.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010267.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010268.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010269.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010270.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010271.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010273.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010274.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010275.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010276.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9289010278.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\928901028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\928901029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280110.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280112.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280114.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280115.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280116.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280117.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328012.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280126.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280129.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280132.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280134.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280136.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280138.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280140.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280143.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280145.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280146.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280147.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280149.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280150.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280151.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280152.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280155.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280156.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280157.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280159.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280164.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280165.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280167.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280212.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280213.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280217.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280218.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280219.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\940328022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280227.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280229.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280234.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280235.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280236.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280238.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280241.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280243.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280245.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280246.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280247.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280249.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280250.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280251.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280254.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280255.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280256.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280259.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280260.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280262.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280265.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280266.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280271.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280272.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280273.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280277.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9403280279.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360111.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360113.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360114.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360115.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360116.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360117.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360120.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360121.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360124.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360125.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360126.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360127.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360128.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360130.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360131.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360132.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360133.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360134.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360135.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360138.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736014.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360140.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360141.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360143.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360147.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360149.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736015.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360151.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360152.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360154.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360156.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360157.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360158.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360159.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736016.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360163.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360164.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360165.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360166.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360168.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360169.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736017.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360170.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360172.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360173.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360174.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360175.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360177.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736018.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360180.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360181.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360182.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360183.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360184.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360185.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360210.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360212.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360213.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360215.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360217.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736022.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360221.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360223.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360225.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360226.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360227.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360228.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360229.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360231.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360232.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360234.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360238.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360239.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736024.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360240.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360241.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360242.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360247.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360248.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736025.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360250.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360252.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360253.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360254.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360256.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360258.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360259.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360261.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360262.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360264.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736027.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360270.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360271.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360273.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360279.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736028.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9877360281.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\987736029.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\998826011.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9988260112.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9988260115.png
# Checking image path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Annote1_Test\9988260119.png
# Train data shape: (5358, 224, 224, 3), Train labels shape: (5358, 4)
# Validation data shape: (1429, 224, 224, 3), Validation labels shape: (1429, 4)
# Test data shape: (1784, 224, 224, 3), Test labels shape: (1784, 4)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers

# Input shape for your images
input_shape = (224, 224, 3)  # Adjust according to your image dimensions and channels

# Define the ResNet50 backbone
def create_resnet50_backbone(input_shape):
    # Load ResNet50 model pretrained on ImageNet without top (fully connected layers)
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    
    # Add additional layers for feature extraction
    inputs = Input(shape=input_shape, name='input_image')
    x = base_model(inputs)
    x = Conv2D(256, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    backbone = Model(inputs, x, name='ResNet50_backbone')
    
    return backbone

# Create ResNet50 backbone
resnet50_backbone = create_resnet50_backbone(input_shape)

# Print summary to see the architecture
resnet50_backbone.summary()
# Out:
# Model: "ResNet50_backbone"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 7, 7, 256)      │     4,718,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 7, 7, 256)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,307,584 (107.98 MB)
#  Trainable params: 28,253,952 (107.78 MB)
#  Non-trainable params: 53,632 (209.50 KB)

# %%
import numpy as np

# Define anchor box scales and aspect ratios
anchor_sizes = [32, 64, 128, 256, 512]  # Sizes of the anchor boxes in pixels
aspect_ratios = [0.5, 1.0, 2.0]  # Aspect ratios of the anchor boxes (width/height)

# Function to generate anchor boxes
def generate_anchor_boxes(base_size, aspect_ratios):
    anchor_boxes = []
    
    for ratio in aspect_ratios:
        width = base_size * np.sqrt(ratio)
        height = base_size / np.sqrt(ratio)
        
        # Create anchor box centered at (0, 0)
        anchor_boxes.append([-width / 2.0, -height / 2.0, width / 2.0, height / 2.0])
    
    return np.array(anchor_boxes)

# Function to generate anchor boxes at different scales and aspect ratios
def generate_all_anchor_boxes(scales, aspect_ratios):
    anchor_boxes = []
    
    for scale in scales:
        anchor_boxes_scale = []
        for size in scale:
            anchor_boxes_scale.extend(generate_anchor_boxes(size, aspect_ratios))
        anchor_boxes.append(anchor_boxes_scale)
    
    return np.array(anchor_boxes)

# Generate anchor boxes
anchor_boxes = generate_all_anchor_boxes([anchor_sizes], aspect_ratios)

# Print anchor boxes
print("Generated Anchor Boxes:")
for i, anchors in enumerate(anchor_boxes):
    print(f"Scale {i}:")
    for j, anchor in enumerate(anchors):
        print(f"Anchor {j}: {anchor}")
# Out:
# Generated Anchor Boxes:
# Scale 0:
# Anchor 0: [-11.3137085 -22.627417   11.3137085  22.627417 ]
# Anchor 1: [-16. -16.  16.  16.]
# Anchor 2: [-22.627417  -11.3137085  22.627417   11.3137085]
# Anchor 3: [-22.627417 -45.254834  22.627417  45.254834]
# Anchor 4: [-32. -32.  32.  32.]
# Anchor 5: [-45.254834 -22.627417  45.254834  22.627417]
# Anchor 6: [-45.254834   -90.50966799  45.254834    90.50966799]
# Anchor 7: [-64. -64.  64.  64.]
# Anchor 8: [-90.50966799 -45.254834    90.50966799  45.254834  ]
# Anchor 9: [ -90.50966799 -181.01933598   90.50966799  181.01933598]
# Anchor 10: [-128. -128.  128.  128.]
# Anchor 11: [-181.01933598  -90.50966799  181.01933598   90.50966799]
# Anchor 12: [-181.01933598 -362.03867197  181.01933598  362.03867197]
# Anchor 13: [-256. -256.  256.  256.]
# Anchor 14: [-362.03867197 -181.01933598  362.03867197  181.01933598]

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Add, Input, UpSampling2D
import tensorflow.keras.backend as K

# Example usage: Obtain ResNet50 backbone outputs
input_shape = (224, 224, 3)  # Example input shape
inputs = Input(shape=input_shape)
resnet50 = ResNet50(weights='imagenet', include_top=False, input_tensor=inputs)

# Accessing ResNet50 backbone outputs
C3_output = resnet50.get_layer('conv3_block4_out').output  # Output from ResNet50 block 3
C4_output = resnet50.get_layer('conv4_block6_out').output  # Output from ResNet50 block 4
C5_output = resnet50.get_layer('conv5_block3_out').output  # Output from ResNet50 block 5

# Function to build FPN
def build_feature_pyramid(backbone_output):
    # Feature Pyramid Network implementation
    C3, C4, C5 = backbone_output
    
    # P5 stage (smallest feature map)
    P5 = Conv2D(256, (1, 1), strides=(1, 1), padding='same', name='P5')(C5)
    
    # P4 stage
    P4 = Add(name='P4_Add')([
        Conv2D(256, (1, 1), strides=(1, 1), padding='same', name='C4_reduced')(C4),
        UpSampling2D(size=(2, 2))(P5)
    ])
    P4 = Conv2D(256, (3, 3), strides=(1, 1), padding='same', name='P4')(P4)
    
    # P3 stage
    P3 = Add(name='P3_Add')([
        Conv2D(256, (1, 1), strides=(1, 1), padding='same', name='C3_reduced')(C3),
        UpSampling2D(size=(2, 2))(P4)
    ])
    P3 = Conv2D(256, (3, 3), strides=(1, 1), padding='same', name='P3')(P3)
    
    # P6 stage (largest feature map)
    P6 = Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='P6')(C5)
    
    # P7 stage (optional, extra large feature map)
    P7 = Conv2D(256, (3, 3), strides=(2, 2), padding='same', name='P7')(Activation('relu')(P6))
    
    return [P3, P4, P5, P6, P7]

# Example usage: Build feature pyramid on ResNet50 outputs
backbone_output = [C3_output, C4_output, C5_output]
feature_pyramid = build_feature_pyramid(backbone_output)

# Print summary to see the architecture
for level, fpn_output in enumerate(feature_pyramid):
    print(f"Feature Pyramid Level {level + 3} (P{level + 3}):")
    print(fpn_output.shape)
# Out:
# Feature Pyramid Level 3 (P3):
# (None, 28, 28, 256)
# Feature Pyramid Level 4 (P4):
# (None, 14, 14, 256)
# Feature Pyramid Level 5 (P5):
# (None, 7, 7, 256)
# Feature Pyramid Level 6 (P6):
# (None, 4, 4, 256)
# Feature Pyramid Level 7 (P7):
# (None, 2, 2, 256)

# %%
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Concatenate, Input
from tensorflow.keras.models import Model

# Function to build RetinaNet head
def build_retinanet_head(num_classes, num_feature_maps, feature_pyramid):
    # Initialize lists to store classification and regression subnetworks
    classification_subnets = []
    regression_subnets = []
    
    # Define number of anchors per feature map level
    num_anchors = 9  # Adjust based on the number of anchor boxes per feature map level
    
    # Loop through each feature map level
    for i in range(num_feature_maps):
        # Classification subnet
        cls_subnet = Conv2D(num_anchors * num_classes, (3, 3), padding='same', name=f'cls_subnet_P{i+3}')(feature_pyramid[i])
        cls_subnet = Flatten(name=f'cls_flatten_P{i+3}')(cls_subnet)
        classification_subnets.append(cls_subnet)
        
        # Regression subnet
        reg_subnet = Conv2D(num_anchors * 4, (3, 3), padding='same', name=f'reg_subnet_P{i+3}')(feature_pyramid[i])
        reg_subnet = Flatten(name=f'reg_flatten_P{i+3}')(reg_subnet)
        regression_subnets.append(reg_subnet)
    
    # Concatenate all subnet outputs
    cls_outputs = Concatenate(axis=1, name='concat_cls')(classification_subnets)
    reg_outputs = Concatenate(axis=1, name='concat_reg')(regression_subnets)
    
    # Classification output
    cls_outputs = Dense(num_anchors * num_classes, activation='sigmoid', name='cls_output')(cls_outputs)
    
    # Regression output
    reg_outputs = Dense(num_anchors * 4, name='reg_output')(reg_outputs)
    
    return cls_outputs, reg_outputs

# Example usage: Build RetinaNet head
num_classes = 4  # Number of classes (Boredom, Engagement, Confusion, Frustration)
num_feature_maps = len(feature_pyramid)  # Number of feature maps (P3 to P7)

# Assuming `feature_pyramid` is defined and contains feature maps P3 to P7
# Constructing the RetinaNet head
cls_outputs, reg_outputs = build_retinanet_head(num_classes, num_feature_maps, feature_pyramid)

# Print summaries to see the architecture
print("Classification Output Shape:", cls_outputs.shape)
print("Regression Output Shape:", reg_outputs.shape)
# Out:
# Classification Output Shape: (None, 36)
# Regression Output Shape: (None, 36)

# %%
import tensorflow as tf

def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, dtype=tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, dtype=tf.float32)
        
        # Clip predictions to avoid log(0) error
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        
        # Compute cross entropy loss
        ce_loss = -y_true * tf.math.log(y_pred)
        
        # Compute the focal loss components
        alpha_factor = y_true * alpha + (1 - y_true) * (1 - alpha)
        modulating_factor = tf.pow(1 - y_pred, gamma)
        
        # Compute the focal loss
        focal_loss = alpha_factor * modulating_factor * ce_loss
        return tf.reduce_sum(focal_loss, axis=1)  # Sum over classes
    
    return focal_loss_fixed



# Smooth L1 Loss for regression
def smooth_l1_loss(sigma=3.0):
    def smooth_l1_loss_fixed(y_true, y_pred):
        diff = tf.abs(y_true - y_pred)
        less_than_one = tf.cast(tf.less(diff, 1.0 / sigma), tf.float32)
        loss = less_than_one * 0.5 * sigma * tf.square(diff) + (1 - less_than_one) * (diff - 0.5 / sigma)
        return tf.reduce_sum(loss, axis=-1)
    
    return smooth_l1_loss_fixed

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define a simple RetinaNet-like model for illustration
def create_model(input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape, name='input_layer_8')
    x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    cls_output = layers.Dense(4, activation='sigmoid', name='cls_output')(x)
    reg_output = layers.Dense(4, activation='linear', name='reg_output')(x)
    model = models.Model(inputs=inputs, outputs=[cls_output, reg_output])
    return model

# Create and compile the model
retinanet_model = create_model()
retinanet_model.compile(optimizer='adam', loss={'cls_output': 'binary_crossentropy', 'reg_output': 'mse'})

# Print the model summary
print(retinanet_model.summary())

# Define the batch size
batch_size = 8

# Check the shapes and types of the data
print(f"Train data shape: {train_data.shape}, Train labels shape: {train_labels.shape}")
print(f"Validation data shape: {val_data.shape}, Validation labels shape: {val_labels.shape}")

# Adjust train_data and train_labels to ensure they match in shape
min_samples = min(train_data.shape[0], train_labels.shape[0])
train_data = train_data[:min_samples]
train_labels = train_labels[:min_samples]

# Log adjusted shapes
print(f"Adjusted Train data shape: {train_data.shape}, Adjusted Train labels shape: {train_labels.shape}")

# Create a generator function
def data_generator(data, labels, batch_size):
    data_size = data.shape[0]
    while True:
        for start in range(0, data_size, batch_size):
            end = min(start + batch_size, data_size)
            yield {'input_layer_8': data[start:end]}, {'cls_output': labels[start:end], 'reg_output': labels[start:end]}

# Create tf.data.Dataset from the generator
train_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(train_data, train_labels, batch_size),
    output_types=({'input_layer_8': tf.float32}, {'cls_output': tf.float32, 'reg_output': tf.float32}),
    output_shapes=({'input_layer_8': (None, 224, 224, 3)}, {'cls_output': (None, 4), 'reg_output': (None, 4)})
).repeat()

min_val_samples = min(val_data.shape[0], val_labels.shape[0])
val_data = val_data[:min_val_samples]
val_labels = val_labels[:min_val_samples]

# Log adjusted shapes
print(f"Adjusted Validation data shape: {val_data.shape}, Adjusted Validation labels shape: {val_labels.shape}")

val_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(val_data, val_labels, batch_size),
    output_types=({'input_layer_8': tf.float32}, {'cls_output': tf.float32, 'reg_output': tf.float32}),
    output_shapes=({'input_layer_8': (None, 224, 224, 3)}, {'cls_output': (None, 4), 'reg_output': (None, 4)})
).repeat()

# Define callbacks
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('retinanet_best.keras', save_best_only=True, monitor='val_loss'),
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5),
    tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

# Increase the number of epochs
epochs = 50

# Train the model
try:
    retinanet_model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=callbacks,
        steps_per_epoch=len(train_data) // batch_size,
        validation_steps=len(val_data) // batch_size
    )
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the model
try:
    retinanet_model.save('retinanet_final.keras')
except Exception as e:
    print(f"An error occurred during model saving: {e}")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 222, 222,  │        896 │ input_layer_8[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 111, 111,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 109, 109,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 54, 54,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 186624)    │          0 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │ 23,888,000 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cls_output (Dense)  │ (None, 4)         │        516 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reg_output (Dense)  │ (None, 4)         │        516 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,908,424 (91.20 MB)
#  Trainable params: 23,908,424 (91.20 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Train data shape: (5358, 224, 224, 3), Train labels shape: (5358, 4)
# Validation data shape: (1429, 224, 224, 3), Validation labels shape: (1429, 4)
# Adjusted Train data shape: (5358, 224, 224, 3), Adjusted Train labels shape: (5358, 4)
# Adjusted Validation data shape: (1429, 224, 224, 3), Adjusted Validation labels shape: (1429, 4)
# Epoch 1/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 402s 597ms/step - loss: 92452.3828 - val_loss: -52632.2344 - learning_rate: 0.0010
# Epoch 2/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 396s 592ms/step - loss: -55957.4531 - val_loss: 188635.5312 - learning_rate: 0.0010
# Epoch 3/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 569ms/step - loss: -288109.0938 - val_loss: -509199.0312 - learning_rate: 0.0010
# Epoch 4/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 567ms/step - loss: -1010254.2500 - val_loss: 1139449.6250 - learning_rate: 0.0010
# Epoch 5/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 378s 565ms/step - loss: -2987191.2500 - val_loss: 17636358.0000 - learning_rate: 0.0010
# Epoch 6/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 376s 562ms/step - loss: -5184740.0000 - val_loss: 74067928.0000 - learning_rate: 0.0010
# Epoch 7/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 566ms/step - loss: -6726817.5000 - val_loss: 106307048.0000 - learning_rate: 0.0010
# Epoch 8/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 566ms/step - loss: -7298220.5000 - val_loss: 22217244.0000 - learning_rate: 0.0010
# Epoch 9/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 569ms/step - loss: -9232764.0000 - val_loss: -25278754.0000 - learning_rate: 1.0000e-04
# Epoch 10/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 384s 574ms/step - loss: -26704604.0000 - val_loss: -44539584.0000 - learning_rate: 1.0000e-04
# Epoch 11/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 388s 580ms/step - loss: -46597296.0000 - val_loss: -72186512.0000 - learning_rate: 1.0000e-04
# Epoch 12/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 406s 606ms/step - loss: -78929208.0000 - val_loss: -82443544.0000 - learning_rate: 1.0000e-04
# Epoch 13/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 423s 633ms/step - loss: -112148568.0000 - val_loss: -131762032.0000 - learning_rate: 1.0000e-04
# Epoch 14/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 413s 618ms/step - loss: -125672504.0000 - val_loss: -44785028.0000 - learning_rate: 1.0000e-04
# Epoch 15/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 568ms/step - loss: -109563000.0000 - val_loss: -94827536.0000 - learning_rate: 1.0000e-04
# Epoch 16/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 383s 573ms/step - loss: -132070976.0000 - val_loss: -97897224.0000 - learning_rate: 1.0000e-04
# Epoch 17/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 375s 561ms/step - loss: -154964048.0000 - val_loss: -90241600.0000 - learning_rate: 1.0000e-04
# Epoch 18/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 372s 556ms/step - loss: -185984608.0000 - val_loss: -112562296.0000 - learning_rate: 1.0000e-04
# Epoch 19/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 374s 559ms/step - loss: -209474480.0000 - val_loss: -159806496.0000 - learning_rate: 1.0000e-05
# Epoch 20/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 386s 577ms/step - loss: -231170768.0000 - val_loss: -178780976.0000 - learning_rate: 1.0000e-05
# Epoch 21/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 375s 561ms/step - loss: -249082080.0000 - val_loss: -192268976.0000 - learning_rate: 1.0000e-05
# Epoch 22/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 372s 555ms/step - loss: -264004176.0000 - val_loss: -205239840.0000 - learning_rate: 1.0000e-05
# Epoch 23/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 376s 562ms/step - loss: -279761472.0000 - val_loss: -218454800.0000 - learning_rate: 1.0000e-05
# Epoch 24/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 373s 557ms/step - loss: -294798208.0000 - val_loss: -234079424.0000 - learning_rate: 1.0000e-05
# Epoch 25/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 569ms/step - loss: -309563328.0000 - val_loss: -249381952.0000 - learning_rate: 1.0000e-05
# Epoch 26/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 383s 573ms/step - loss: -323533920.0000 - val_loss: -263559568.0000 - learning_rate: 1.0000e-05
# Epoch 27/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 384s 574ms/step - loss: -337158560.0000 - val_loss: -278706752.0000 - learning_rate: 1.0000e-05
# Epoch 28/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 567ms/step - loss: -352913248.0000 - val_loss: -293224224.0000 - learning_rate: 1.0000e-05
# Epoch 29/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 568ms/step - loss: -366656928.0000 - val_loss: -307945408.0000 - learning_rate: 1.0000e-05
# Epoch 30/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 378s 565ms/step - loss: -382014304.0000 - val_loss: -321641408.0000 - learning_rate: 1.0000e-05
# Epoch 31/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -396366560.0000 - val_loss: -336200896.0000 - learning_rate: 1.0000e-05
# Epoch 32/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -411175136.0000 - val_loss: -349135744.0000 - learning_rate: 1.0000e-05
# Epoch 33/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -426724608.0000 - val_loss: -362240256.0000 - learning_rate: 1.0000e-05
# Epoch 34/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 567ms/step - loss: -442040864.0000 - val_loss: -372381632.0000 - learning_rate: 1.0000e-05
# Epoch 35/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 377s 564ms/step - loss: -458733280.0000 - val_loss: -378595328.0000 - learning_rate: 1.0000e-05
# Epoch 36/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 377s 564ms/step - loss: -475430240.0000 - val_loss: -381139008.0000 - learning_rate: 1.0000e-05
# Epoch 37/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 567ms/step - loss: -491209792.0000 - val_loss: -382472192.0000 - learning_rate: 1.0000e-05
# Epoch 38/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 377s 563ms/step - loss: -507682496.0000 - val_loss: -381815392.0000 - learning_rate: 1.0000e-05
# Epoch 39/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -524318944.0000 - val_loss: -384417696.0000 - learning_rate: 1.0000e-05
# Epoch 40/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 387s 578ms/step - loss: -542427776.0000 - val_loss: -389437600.0000 - learning_rate: 1.0000e-05
# Epoch 41/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 384s 573ms/step - loss: -556901504.0000 - val_loss: -399333408.0000 - learning_rate: 1.0000e-05
# Epoch 42/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -572297600.0000 - val_loss: -410092192.0000 - learning_rate: 1.0000e-05
# Epoch 43/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -589108736.0000 - val_loss: -422743360.0000 - learning_rate: 1.0000e-05
# Epoch 44/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 388s 579ms/step - loss: -605975360.0000 - val_loss: -443253312.0000 - learning_rate: 1.0000e-05
# Epoch 45/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 381s 570ms/step - loss: -623922880.0000 - val_loss: -465017024.0000 - learning_rate: 1.0000e-05
# Epoch 46/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 380s 568ms/step - loss: -645137024.0000 - val_loss: -487876544.0000 - learning_rate: 1.0000e-05
# Epoch 47/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 567ms/step - loss: -665260032.0000 - val_loss: -512807776.0000 - learning_rate: 1.0000e-05
# Epoch 48/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 567ms/step - loss: -685950400.0000 - val_loss: -539642176.0000 - learning_rate: 1.0000e-05
# Epoch 49/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 379s 567ms/step - loss: -706327680.0000 - val_loss: -571614336.0000 - learning_rate: 1.0000e-05
# Epoch 50/50
# 669/669 ━━━━━━━━━━━━━━━━━━━━ 382s 571ms/step - loss: -727633792.0000 - val_loss: -602911808.0000 - learning_rate: 1.0000e-05

# %%
# Load the best weights into the model
try:
    retinanet_model.load_weights('retinanet_best.keras')
    print("Weights loaded successfully.")
except Exception as e:
    print(f"An error occurred while loading weights: {e}")
# Out:
# Weights loaded successfully.

# %%
# Evaluate the model on the validation data
validation_loss = retinanet_model.evaluate(val_dataset, steps=len(val_data) // batch_size)
print(f"Validation loss: {validation_loss}")
# Out:
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: -584165440.0000
# Validation loss: -603042048.0

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load and preprocess image
def load_image(image_path, img_size=(224, 224)):
    img = cv2.imread(image_path)
    if img is not None:
        img = cv2.resize(img, img_size)
        img = img.astype(np.float32) / 255.0  # Normalize image to [0, 1]
        return img
    else:
        raise FileNotFoundError(f"Image not found at path: {image_path}")

# Post-process model predictions
def postprocess_predictions(predictions, img_shape, score_threshold=0.5):
    boxes, class_probs = predictions
    boxes = np.squeeze(boxes)  # Remove batch dimension
    class_probs = np.squeeze(class_probs)
    
    # Filter out low confidence boxes
    scores = np.max(class_probs, axis=-1)
    classes = np.argmax(class_probs, axis=-1)
    
    keep = scores >= score_threshold
    boxes = boxes[keep]
    scores = scores[keep]
    classes = classes[keep]

    return boxes, scores, classes

# Display the image with bounding boxes
def show_image_with_prediction(image, boxes, scores, classes, categories, figsize=(12, 12)):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert image to RGB
    plt.figure(figsize=figsize)
    plt.imshow(image)
    
    for box, score, _class in zip(boxes, scores, classes):
        x1, y1, x2, y2 = box
        plt.gca().add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, edgecolor='red', fill=False, linewidth=2))
        plt.text(x1, y1, f'{categories[_class]}: {score:.2f}', bbox={'facecolor': 'yellow', 'alpha': 0.5}, fontsize=12, color='black')
    
    plt.axis('off')
    plt.show()

# Corrected path to the new image
new_image_path = "D:\Data_sets\DAiSEE\DAiSEE\DataSet\Test1_Frames\928901\928901013\928901013.png"

# Load the new image
try:
    new_data = load_image(new_image_path)
    new_data = np.expand_dims(new_data, axis=0)  # Add batch dimension
    print(f"Loaded image shape: {new_data.shape}")
except Exception as e:
    print(f"Error loading image: {e}")

# Define categories
categories = ['Boredom', 'Engagement', 'Confusion', 'Frustration']

# Ensure the model is loaded
try:
    retinanet_model = tf.keras.models.load_model('retinanet_final.keras', compile=False)
except Exception as e:
    print(f"Error loading model: {e}")

if 'retinanet_model' in locals():
    if new_data.shape[0] > 0:
        # Make predictions on the new image
        predictions = retinanet_model.predict(new_data)

        # Post-process predictions
        boxes, scores, classes = postprocess_predictions(predictions, new_data.shape[1:])

        # Show the image with its prediction
        print(f"Image: {os.path.basename(new_image_path)}")
        print(f"Prediction boxes: {boxes}")
        print(f"Prediction scores: {scores}")
        print(f"Prediction classes: {classes}")
        show_image_with_prediction(new_data[0], boxes, scores, classes, categories)
    else:
        print("No data loaded. Please check the input path and data format.")
else:
    print("Model is not loaded. Please load the model before making predictions.")
# Out:
# Loaded image shape: (1, 224, 224, 3)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D222DC2F20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Image: 928901013.png
# Prediction boxes: [[0.0000000e+00 1.0000000e+00 0.0000000e+00 3.6647704e-18]]
# Prediction scores: [88.817726]
# Prediction classes: [3]

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load and preprocess image
def load_image(image_path, img_size=(224, 224)):
    img = cv2.imread(image_path)
    if img is not None:
        img = cv2.resize(img, img_size)
        img = img.astype(np.float32) / 255.0  # Normalize image to [0, 1]
        return img
    else:
        raise FileNotFoundError(f"Image not found at path: {image_path}")

# Post-process model predictions
def postprocess_predictions(predictions, img_shape, score_threshold=0.5):
    boxes, class_probs = predictions
    boxes = np.squeeze(boxes)  # Remove batch dimension
    class_probs = np.squeeze(class_probs)
    
    # Filter out low confidence boxes
    scores = np.max(class_probs, axis=-1)
    classes = np.argmax(class_probs, axis=-1)
    
    keep = scores >= score_threshold
    boxes = boxes[keep]
    scores = scores[keep]
    classes = classes[keep]

    return boxes, scores, classes

# Display the image with bounding boxes and save the result
def show_and_save_image_with_prediction(image, boxes, scores, classes, categories, output_path, figsize=(12, 12)):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert image to RGB
    plt.figure(figsize=figsize)
    plt.imshow(image)
    
    for box, score, _class in zip(boxes, scores, classes):
        x1, y1, x2, y2 = box
        plt.gca().add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, edgecolor='red', fill=False, linewidth=2))
        plt.text(x1, y1, f'{categories[_class]}: {score:.2f}', bbox={'facecolor': 'yellow', 'alpha': 0.5}, fontsize=12, color='black')
    
    plt.axis('off')

    # Save the image
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
    
    # Display the image in the notebook
    plt.show()

# Corrected path to the new image
new_image_path = "D:\Data_sets\DAiSEE\DAiSEE\DataSet\Test1_Frames\510042\5100421007\5100421007.png"

# Load the new image
try:
    new_data = load_image(new_image_path)
    new_data = np.expand_dims(new_data, axis=0)  # Add batch dimension
    print(f"Loaded image shape: {new_data.shape}")
except Exception as e:
    print(f"Error loading image: {e}")

# Define categories
categories = ['Boredom', 'Engagement', 'Confusion', 'Frustration']

# Ensure the model is loaded
try:
    retinanet_model = tf.keras.models.load_model('retinanet_final.keras', compile=False)
except Exception as e:
    print(f"Error loading model: {e}")

if 'retinanet_model' in locals():
    if new_data.shape[0] > 0:
        # Make predictions on the new image
        predictions = retinanet_model.predict(new_data)

        # Post-process predictions
        boxes, scores, classes = postprocess_predictions(predictions, new_data.shape[1:])

        # Create the output path with "predicted_" prefix
        base_name = os.path.basename(new_image_path)
        output_name = f"predicted_{base_name}"
        output_path = os.path.join("D:\Data_sets\DAiSEE\DAiSEE\DataSet\Output", output_name)
        
        # Show and save the image with its prediction
        print(f"Image: {base_name}")
        print(f"Prediction boxes: {boxes}")
        print(f"Prediction scores: {scores}")
        print(f"Prediction classes: {classes}")
        show_and_save_image_with_prediction(new_data[0], boxes, scores, classes, categories, output_path)
        print(f"Output image saved at: {output_path}")
    else:
        print("No data loaded. Please check the input path and data format.")
else:
    print("Model is not loaded. Please load the model before making predictions.")
# Out:
# Error loading image: Image not found at path: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Test1_Framesň042ň0421007ň0421007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Image: Test1_Framesň042ň0421007ň0421007.png
# Prediction boxes: [[0.0000000e+00 1.0000000e+00 0.0000000e+00 3.6647704e-18]]
# Prediction scores: [88.817726]
# Prediction classes: [3]
# Output image saved at: D:\Data_sets\DAiSEE\DAiSEE\DataSet\Output\predicted_Test1_Framesň042ň0421007ň0421007.png
